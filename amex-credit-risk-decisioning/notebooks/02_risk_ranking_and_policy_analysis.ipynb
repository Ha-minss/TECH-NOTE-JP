# %% [markdown]
# # Risk Ranking And Policy Analysis
#
# This notebook reviews aggregate Top-K, weighted scenario, decile, and Base cost-scenario outputs. Synthetic data is not used for reported performance.

# %%
import pandas as pd

topk = pd.read_csv('../outputs/tables/topk_policy_tradeoff.csv')
weighted = pd.read_csv('../outputs/tables/weighted_policy_tradeoff.csv')
top17 = pd.read_csv('../outputs/tables/top17_base_cost_scenario.csv')
decile = pd.read_csv('../outputs/tables/risk_decile_summary.csv')

display(topk)
display(weighted)
display(top17)
display(decile)
