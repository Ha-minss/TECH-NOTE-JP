# %% [markdown]
# # Model Development Summary
#
# This notebook summarizes verified model-development outputs from `outputs/tables/model_cv_summary.csv`. It does not train models or create new performance numbers.

# %%
import pandas as pd

model_cv = pd.read_csv('../outputs/tables/model_cv_summary.csv')
blend = pd.read_csv('../outputs/tables/blend_comparison.csv')
display(model_cv)
display(blend)
