# %%
# !git clone https://github.com/Ha-minss/Portfolio.git
# %cd Portfolio/Causal_Inference_SECA
# !ls
# Out:
# Cloning into 'Portfolio'...
# remote: Enumerating objects: 172, done.
# remote: Counting objects: 100% (172/172), done.
# remote: Compressing objects: 100% (147/147), done.
# remote: Total 172 (delta 43), reused 108 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (172/172), 7.06 MiB | 16.63 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# /content/Portfolio/Causal_Inference_SECA
# data  README.md  requirements.txt  scripts  step1_did

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 46.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 8.1 MB/s eta 0:00:00
# ...

# %%
# !ls -lh data
# !head -n 2 data/df_iv.csv
# Out:
# total 7.1M
# -rw-r--r-- 1 root root 7.1M Jan  7 03:02 df_iv.csv
# -rw-r--r-- 1 root root  268 Jan  7 03:02 README.md
# ...

# %%
# %cd /content/Portfolio/Causal_Inference_SECA

# !ls -la
# !ls -la step1_did

# !touch step1_did/__init__.py

# !PYTHONPATH=$PWD:$PYTHONPATH python scripts/01_main_did_step1.py
# !PYTHONPATH=$PWD:$PYTHONPATH python scripts/02_event_study_step1.py
# !PYTHONPATH=$PWD:$PYTHONPATH python scripts/03_robustness_suite_step1.py
# !PYTHONPATH=$PWD:$PYTHONPATH python scripts/05_treatment_defs_step1.py
# !PYTHONPATH=$PWD:$PYTHONPATH python scripts/04_level_so2_ols_ppml.py
# Out:
# /content/Portfolio/Causal_Inference_SECA
# total 36
# drwxr-xr-x 5 root root 4096 Jan  7 03:02 .
# drwxr-xr-x 5 root root 4096 Jan  7 03:02 ..
# drwxr-xr-x 2 root root 4096 Jan  7 03:02 data
# -rw-r--r-- 1 root root  175 Jan  7 03:02 .gitignore
# -rw-r--r-- 1 root root 5441 Jan  7 03:02 README.md
# -rw-r--r-- 1 root root  102 Jan  7 03:02 requirements.txt
# drwxr-xr-x 2 root root 4096 Jan  7 03:02 scripts
# drwxr-xr-x 2 root root 4096 Jan  7 03:02 step1_did
# total 36
# drwxr-xr-x 2 root root 4096 Jan  7 03:02 .
# drwxr-xr-x 5 root root 4096 Jan  7 03:02 ..
# -rw-r--r-- 1 root root 1163 Jan  7 03:02 config.py
# -rw-r--r-- 1 root root   62 Jan  7 03:02 __init__.py
# -rw-r--r-- 1 root root  428 Jan  7 03:02 io.py
# -rw-r--r-- 1 root root  902 Jan  7 03:02 models.py
# -rw-r--r-- 1 root root 1776 Jan  7 03:02 prep.py
# -rw-r--r-- 1 root root 1201 Jan  7 03:02 utils.py
# -rw-r--r-- 1 root root 2085 Jan  7 03:02 wild.py
#
# ...
# M0_FE_only | [NONE]
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("outputs/event_study_step1_M2.png")
plt.figure(figsize=(12,4))
plt.imshow(img)
plt.axis("off")
plt.show()
